# %% [markdown]
# <h1>How to install</h1>
# <h2>pip install matplotlib</h2>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

# %%
plt.xlabel('Day')
plt.ylabel('Tempeature')
plt.title('Weather')
plt.plot(x,y,color='green', linewidth=5, linestyle='dotted')
