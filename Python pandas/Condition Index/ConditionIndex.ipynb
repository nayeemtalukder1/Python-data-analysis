# %% [markdown]
# <h1>How to import Pandas</h1>

# %%
import pandas as pd
df = pd.read_csv("Mymensingh.csv")

# %%
df
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 0      1  Mymensingh  1960      1  16.9  11.3  2.0  73.39  1016.0     15
# 1      2  Mymensingh  1960      2  21.4  12.6  1.7  66.34  1013.0      0
# 2      3  Mymensingh  1960      3  24.1  14.9  2.3  64.13  1011.4     69
# 3      4  Mymensingh  1960      4  29.9  17.6  2.2  59.03  1007.1     27
# 4      5  Mymensingh  1960      5  29.6  23.2  2.4  73.45  1003.4    187
# ..   ...         ...   ...    ...   ...   ...  ...    ...     ...    ...
# 667  668  Mymensingh  2015      8  28.7  26.2  2.5  87.10  1003.3    349
# 668  669  Mymensingh  2015      9  28.8  25.2  2.0  85.63  1006.0    263
# 669  670  Mymensingh  2015     10  27.0  23.5  2.0  82.48  1011.3    180
# 670  671  Mymensingh  2015     11  23.1  18.7  1.7  81.73  1013.7     13
# 671  672  Mymensingh  2015     12  18.3  14.9  1.8  82.68  1015.9      5
#
#      A_RAIN  RAN
# 0      0.48  NRT
# 1      0.00  NRT
# 2      2.23  LTR
# 3      0.90  NRT
# ...

# %% [markdown]
# <h2>Input data by Dictionary</h2>

# %%
weather_data = {
    'ID': [1,2],
    'TEM': [16.9,21.4]
}

df = pd.DataFrame(weather_data)

# %%
df
# Out:
#    ID   TEM
# 0   1  16.9
# 1   2  21.4

# %% [markdown]
# <h2>Show rows and columns</h2>

# %%
df.shape
# Out:
# (2, 2)

# %%
rows, columns = df.shape

# %%
columns
# Out:
# 2

# %%
rows
# Out:
# 2

# %%
df = pd.read_csv("Mymensingh.csv")

df.head()
# Out:
#    ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  A_RAIN  \
# 0   1  Mymensingh  1960      1  16.9  11.3  2.0  73.39  1016.0     15    0.48
# 1   2  Mymensingh  1960      2  21.4  12.6  1.7  66.34  1013.0      0    0.00
# 2   3  Mymensingh  1960      3  24.1  14.9  2.3  64.13  1011.4     69    2.23
# 3   4  Mymensingh  1960      4  29.9  17.6  2.2  59.03  1007.1     27    0.90
# 4   5  Mymensingh  1960      5  29.6  23.2  2.4  73.45  1003.4    187    6.03
#
#    RAN
# 0  NRT
# 1  NRT
# 2  LTR
# 3  NRT
# 4  LTR

# %%
df.head(2)
# Out:
#    ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  A_RAIN  \
# 0   1  Mymensingh  1960      1  16.9  11.3  2.0  73.39  1016.0     15    0.48
# 1   2  Mymensingh  1960      2  21.4  12.6  1.7  66.34  1013.0      0    0.00
#
#    RAN
# 0  NRT
# 1  NRT

# %%
df.tail()
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 667  668  Mymensingh  2015      8  28.7  26.2  2.5  87.10  1003.3    349
# 668  669  Mymensingh  2015      9  28.8  25.2  2.0  85.63  1006.0    263
# 669  670  Mymensingh  2015     10  27.0  23.5  2.0  82.48  1011.3    180
# 670  671  Mymensingh  2015     11  23.1  18.7  1.7  81.73  1013.7     13
# 671  672  Mymensingh  2015     12  18.3  14.9  1.8  82.68  1015.9      5
#
#      A_RAIN  RAN
# 667   11.26  MHR
# 668    8.77  LTR
# 669    5.81  LTR
# 670    0.43  NRT
# 671    0.16  NRT

# %%
df.tail(1)
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 671  672  Mymensingh  2015     12  18.3  14.9  1.8  82.68  1015.9      5
#
#      A_RAIN  RAN
# 671    0.16  NRT

# %%
df[2:10]
# Out:
#    ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  A_RAIN  \
# 2   3  Mymensingh  1960      3  24.1  14.9  2.3  64.13  1011.4     69    2.23
# 3   4  Mymensingh  1960      4  29.9  17.6  2.2  59.03  1007.1     27    0.90
# 4   5  Mymensingh  1960      5  29.6  23.2  2.4  73.45  1003.4    187    6.03
# 5   6  Mymensingh  1960      6  28.2  24.1  2.0  84.03  1001.6    363   12.10
# 6   7  Mymensingh  1960      7  27.7  25.2  2.2  87.87  1002.0    383   12.35
# 7   8  Mymensingh  1960      8  28.7  25.6  3.0  85.65  1000.5    355   11.45
# 8   9  Mymensingh  1960      9  28.0  24.6  1.6  87.63  1005.0    579   19.30
# 9  10  Mymensingh  1960     10  27.0  22.9  1.5  80.58  1009.9     53    1.71
#
#    RAN
# 2  LTR
# 3  NRT
# 4  LTR
# 5  MHR
# 6  MHR
# 7  MHR
# 8  MHR
# 9  LTR

# %%
df.columns
# Out:
# Index(['ID', 'Station', 'Year', 'Month', 'TEM', 'DPT', 'WIS', 'HUM', 'SLP',
#        'T_RAN', 'A_RAIN', 'RAN'],
#       dtype='object')

# %%
df.ID
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 667    668
# 668    669
# 669    670
# 670    671
# 671    672
# Name: ID, Length: 672, dtype: int64

# %%
df.Station
# Out:
# 0      Mymensingh
# 1      Mymensingh
# 2      Mymensingh
# 3      Mymensingh
# 4      Mymensingh
#           ...
# 667    Mymensingh
# 668    Mymensingh
# 669    Mymensingh
# 670    Mymensingh
# 671    Mymensingh
# Name: Station, Length: 672, dtype: object

# %%
df['TEM']
# Out:
# 0      16.9
# 1      21.4
# 2      24.1
# 3      29.9
# 4      29.6
#        ...
# 667    28.7
# 668    28.8
# 669    27.0
# 670    23.1
# 671    18.3
# Name: TEM, Length: 672, dtype: float64

# %%
type(df['TEM'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 0      1  Mymensingh  1960      1  16.9  11.3  2.0  73.39  1016.0     15
# 1      2  Mymensingh  1960      2  21.4  12.6  1.7  66.34  1013.0      0
# 2      3  Mymensingh  1960      3  24.1  14.9  2.3  64.13  1011.4     69
# 3      4  Mymensingh  1960      4  29.9  17.6  2.2  59.03  1007.1     27
# 4      5  Mymensingh  1960      5  29.6  23.2  2.4  73.45  1003.4    187
# ..   ...         ...   ...    ...   ...   ...  ...    ...     ...    ...
# 667  668  Mymensingh  2015      8  28.7  26.2  2.5  87.10  1003.3    349
# 668  669  Mymensingh  2015      9  28.8  25.2  2.0  85.63  1006.0    263
# 669  670  Mymensingh  2015     10  27.0  23.5  2.0  82.48  1011.3    180
# 670  671  Mymensingh  2015     11  23.1  18.7  1.7  81.73  1013.7     13
# 671  672  Mymensingh  2015     12  18.3  14.9  1.8  82.68  1015.9      5
#
#      A_RAIN  RAN
# 0      0.48  NRT
# 1      0.00  NRT
# 2      2.23  LTR
# 3      0.90  NRT
# ...

# %%
df[['ID','TEM']]
# Out:
#       ID   TEM
# 0      1  16.9
# 1      2  21.4
# 2      3  24.1
# 3      4  29.9
# 4      5  29.6
# ..   ...   ...
# 667  668  28.7
# 668  669  28.8
# 669  670  27.0
# 670  671  23.1
# 671  672  18.3
#
# [672 rows x 2 columns]

# %% [markdown]
# <h1>Max,Min,Standerd division,Describe</h1>

# %%
df['TEM'].max()
# Out:
# 30.9

# %%
df['TEM'].min()
# Out:
# 15.4

# %%
df['TEM'].std()
# Out:
# 3.856699843844089

# %%
df['TEM'].describe()
# Out:
# count    654.000000
# mean      25.289602
# std        3.856700
# min       15.400000
# 25%       22.525000
# 50%       27.000000
# 75%       28.300000
# max       30.900000
# Name: TEM, dtype: float64

# %% [markdown]
# <h1>Use Conditions</h1>

# %%
df[df.TEM>=30]
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 75    76  Mymensingh  1966      4  30.1  19.7  1.9  62.53  1006.2    110
# 124  125  Mymensingh  1970      5  30.0  23.7  1.6  72.71  1003.8    176
# 162  163  Mymensingh  1973      7  30.1  25.6  1.7  79.20   998.6    162
# 243  244  Mymensingh  1980      4  30.9  20.8  7.5  60.27  1006.3     84
# 257  258  Mymensingh  1981      6  30.5  24.5  4.3  75.93  1000.3    103
# 268  269  Mymensingh  1982      5  30.4  24.0  5.4  71.00  1006.1    276
# 271  272  Mymensingh  1982      8  30.0  25.5  5.4  78.32  1000.3    337
#
#      A_RAIN  RAN
# 75     3.67  LTR
# 124    5.68  LTR
# 162    5.23  LTR
# 243    2.80  LTR
# 257    3.43  LTR
# 268    8.90  LTR
# 271   10.87  MHR

# %%
df[df['TEM']>=30]
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 75    76  Mymensingh  1966      4  30.1  19.7  1.9  62.53  1006.2    110
# 124  125  Mymensingh  1970      5  30.0  23.7  1.6  72.71  1003.8    176
# 162  163  Mymensingh  1973      7  30.1  25.6  1.7  79.20   998.6    162
# 243  244  Mymensingh  1980      4  30.9  20.8  7.5  60.27  1006.3     84
# 257  258  Mymensingh  1981      6  30.5  24.5  4.3  75.93  1000.3    103
# 268  269  Mymensingh  1982      5  30.4  24.0  5.4  71.00  1006.1    276
# 271  272  Mymensingh  1982      8  30.0  25.5  5.4  78.32  1000.3    337
#
#      A_RAIN  RAN
# 75     3.67  LTR
# 124    5.68  LTR
# 162    5.23  LTR
# 243    2.80  LTR
# 257    3.43  LTR
# 268    8.90  LTR
# 271   10.87  MHR

# %%
df[df.TEM==df['TEM'].max()]
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 243  244  Mymensingh  1980      4  30.9  20.8  7.5  60.27  1006.3     84
#
#      A_RAIN  RAN
# 243     2.8  LTR

# %%
df['Year'][df.TEM==df['TEM'].max()]
# Out:
# 243    1980
# Name: Year, dtype: int64

# %%
df[['Year','TEM']][df.TEM==df['TEM'].max()]
# Out:
#      Year   TEM
# 243  1980  30.9

# %% [markdown]
# <h1>Index Set</h1>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=672, step=1)

# %%
df.set_index('ID',inplace=True)

# %%
df
# Out:
#         Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  A_RAIN  \
# ID
# 1    Mymensingh  1960      1  16.9  11.3  2.0  73.39  1016.0     15    0.48
# 2    Mymensingh  1960      2  21.4  12.6  1.7  66.34  1013.0      0    0.00
# 3    Mymensingh  1960      3  24.1  14.9  2.3  64.13  1011.4     69    2.23
# 4    Mymensingh  1960      4  29.9  17.6  2.2  59.03  1007.1     27    0.90
# 5    Mymensingh  1960      5  29.6  23.2  2.4  73.45  1003.4    187    6.03
# ..          ...   ...    ...   ...   ...  ...    ...     ...    ...     ...
# 668  Mymensingh  2015      8  28.7  26.2  2.5  87.10  1003.3    349   11.26
# 669  Mymensingh  2015      9  28.8  25.2  2.0  85.63  1006.0    263    8.77
# 670  Mymensingh  2015     10  27.0  23.5  2.0  82.48  1011.3    180    5.81
# 671  Mymensingh  2015     11  23.1  18.7  1.7  81.73  1013.7     13    0.43
# 672  Mymensingh  2015     12  18.3  14.9  1.8  82.68  1015.9      5    0.16
#
#      RAN
# ID
# 1    NRT
# 2    NRT
# 3    LTR
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       ID     Station  Year  Month   TEM   DPT  WIS    HUM     SLP  T_RAN  \
# 0      1  Mymensingh  1960      1  16.9  11.3  2.0  73.39  1016.0     15
# 1      2  Mymensingh  1960      2  21.4  12.6  1.7  66.34  1013.0      0
# 2      3  Mymensingh  1960      3  24.1  14.9  2.3  64.13  1011.4     69
# 3      4  Mymensingh  1960      4  29.9  17.6  2.2  59.03  1007.1     27
# 4      5  Mymensingh  1960      5  29.6  23.2  2.4  73.45  1003.4    187
# ..   ...         ...   ...    ...   ...   ...  ...    ...     ...    ...
# 667  668  Mymensingh  2015      8  28.7  26.2  2.5  87.10  1003.3    349
# 668  669  Mymensingh  2015      9  28.8  25.2  2.0  85.63  1006.0    263
# 669  670  Mymensingh  2015     10  27.0  23.5  2.0  82.48  1011.3    180
# 670  671  Mymensingh  2015     11  23.1  18.7  1.7  81.73  1013.7     13
# 671  672  Mymensingh  2015     12  18.3  14.9  1.8  82.68  1015.9      5
#
#      A_RAIN  RAN
# 0      0.48  NRT
# 1      0.00  NRT
# 2      2.23  LTR
# 3      0.90  NRT
# ...

# %% [markdown]
# get by index

# %%
df.loc[667]
# Out:
# ID                668
# Station    Mymensingh
# Year             2015
# Month               8
# TEM              28.7
# DPT              26.2
# WIS               2.5
# HUM              87.1
# SLP            1003.3
# T_RAN             349
# A_RAIN          11.26
# RAN               MHR
# Name: 667, dtype: object
